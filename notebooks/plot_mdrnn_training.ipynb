# %%
import json
import numpy as np 
import matplotlib.pyplot as plt

loss_dict = json.load(open('../exp_dir/mdrnn/logger.json', 'r'))

# %%
loss_dict.keys()
# Out:
# dict_keys(['train_gmm', 'test_gmm', 'test_overshoot', 'train_mse', 'test_mse', 'train_loss', 'train_overshoot', 'test_loss'])

# %%
for key in ['train', 'test']:
    for typee in ['loss', 'overshoot', 'gmm', 'mse']:
        val = key+'_'+typee
        plt.figure()
        plt.plot(loss_dict[val], label=val)

        plt.legend()
        #plt.ylim([-2, 200])
        plt.ylabel('loss')
        plt.xlabel('epochs')

# %%
plt.plot(loss_dict['train_overshoot'], label='train')
plt.plot(loss_dict['test_overshoot'], label='test')
plt.legend()
#plt.ylim([-2, 100])
plt.ylabel('mse')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(loss_dict['train_mse'], label='train')
plt.plot(loss_dict['test_mse'], label='test')
plt.legend()
#plt.ylim([-2, 100])
plt.ylabel('mse')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(loss_dict['train_gmm'], label='train')
plt.plot(loss_dict['test_gmm'], label='test')
plt.legend()
#plt.ylim([-2, 10])
plt.ylabel('mse')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')
