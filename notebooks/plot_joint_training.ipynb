# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
mdrnn_vae_training = pd.read_csv('../exp_dir/joint/logger.txt', sep=' ')
mdrnn_vae_training.reset_index(inplace=True)
mdrnn_vae_training
# Out:
#     index  train_gmm  train_loss_vae  train_bce  train_kld  train_recon  \
# 0       0     -2.178      -45081.655      0.000    124.433    45206.087
# 1       1     -2.214      -65275.458      0.000    125.267    65400.725
# 2       2     -2.259      -71545.864      0.000    122.140    71668.004
# 3       3     -2.246      -69529.859      0.000    121.632    69651.491
# 4       4     -2.370      -66538.684      0.000    128.470    66667.154
# 5       5     -2.348       12056.667      0.000    124.120   -11932.541
# 6       6     -2.423      -70597.419      0.000    131.575    70728.994
# 7       7     -2.117       70407.177    124.299      0.116       -2.001
# 8       8     -2.324       66679.399    135.825      0.195       -2.128
# 9       9     -2.328       72865.524    136.885      0.079       -2.250
# 10     10     -2.334       55193.289    129.067      0.106       -2.229
# 11     11     -2.385       74474.260    137.756      0.095       -2.290
# 12     12     -2.322       79925.310    135.155      0.070       -2.251
# 13     13     -2.240       72579.555    135.946      0.121       -2.120
# 14     14     -2.314       76543.380    138.126      0.096       -2.218
# 15     15     -2.292       73433.137    144.812      0.075       -2.217
# 16     16     -2.347       73673.917    136.731      0.102       -2.245
# 17     17     -2.326       77150.913    133.508      0.086       -2.239
# 18     18     -2.443       79526.225    138.172      0.092       -2.350
# 19     19     -2.270       75906.034    139.900      0.084       -2.186
# 20     20     -2.307       76998.972    140.698      0.058       -2.249
# 21     21     -2.265       76648.998    144.152      0.084       -2.181
# 22     22     -2.289       77745.402    142.268      0.097       -2.192
# 23     23     -2.267       74260.465    144.662      0.071       -2.196
# 24     24     -2.272       51475.732    137.992      0.068       -2.204
# 25     25     -2.266       76614.349    140.452      0.041       -2.224
# 26     26     -2.235       75273.968    141.166      0.060       -2.175
#
#     train_mse  train_loss_mdrnn  train_loss  test_bce  ...  test_loss_mdrnn  \
# 0       0.137            -2.042  -45083.696     0.000  ...           -2.085
# 1       0.196            -2.018  -65277.475     0.000  ...           -2.245
# 2       0.185            -2.074  -71547.938     0.000  ...           -1.947
# 3       0.196            -2.050  -69531.909     0.000  ...           -2.027
# 4       0.131            -2.239  -66540.923     0.000  ...           -1.791
# 5       0.171            -2.177   12054.491     0.000  ...           -2.105
# 6       0.150            -2.274  -70599.693     0.000  ...           -2.483
# 7       0.000        -70282.879  -70284.879     0.000  ...            0.000
# 8       0.000        -66543.574  -66545.703     0.000  ...            0.000
# 9       0.000        -72728.639  -72730.889     0.000  ...            0.000
# 10      0.000        -55064.222  -55066.451     0.000  ...            0.000
# 11      0.000        -74336.504  -74338.794     0.000  ...            0.000
# 12      0.000        -79790.154  -79792.405     0.000  ...            0.000
# 13      0.000        -72443.609  -72445.729     0.000  ...            0.000
# 14      0.000        -76405.254  -76407.472     0.000  ...            0.000
# 15      0.000        -73288.325  -73290.542     0.000  ...            0.000
# 16      0.000        -73537.187  -73539.432     0.000  ...            0.000
# 17      0.000        -77017.405  -77019.644     0.000  ...            0.000
# 18      0.000        -79388.052  -79390.402     0.000  ...            0.000
# 19      0.000        -75766.135  -75768.321     0.000  ...            0.000
# 20      0.000        -76858.273  -76860.523     0.000  ...            0.000
# 21      0.000        -76504.846  -76507.027     0.000  ...            0.000
# 22      0.000        -77603.133  -77605.326     0.000  ...            0.000
# 23      0.000        -74115.803  -74117.999     0.000  ...            0.000
# 24      0.000        -51337.737  -51339.941     0.000  ...            0.000
# 25      0.000        -76473.896  -76476.121     0.000  ...            0.000
# 26      0.000        -75132.803  -75134.977     0.000  ...            0.000
#
#     test_kld     test_recon  test_std_reward_planner  \
# 0    122.978      70159.308                   25.548
# 1    118.417      63233.985                   37.562
# 2    122.089      58694.632                   28.028
# 3    122.009      66276.087                   45.988
# 4    139.736      51288.793                   28.395
# 5    125.220      62471.429                   46.981
# 6    129.980 -174080480.386                   51.640
# 7     -2.257      77285.670                  -76.351
# 8     -2.273    -305488.360                  -89.830
# 9     -2.470   -4978777.349                  -92.944
# 10    -2.358      83565.458                  -95.029
# 11    -2.459      79928.407                 -104.883
# 12    -2.056     -84557.834                  -74.763
# 13    -2.135      62852.055                  -76.048
# 14    -2.260      75104.951                  -75.758
# 15    -2.294      78644.328                  -74.910
# 16    -2.381      79399.525                  -75.610
# 17    -2.196      52073.347                  -76.271
# 18    -2.457      81189.100                  -71.698
# 19    -2.129      63318.566                  -73.684
# 20    -2.440      78940.736                  -71.930
# 21    -2.196      63222.091                  -76.974
# 22    -2.157      68378.176                  -72.028
# 23    -2.065      71502.570                  -77.636
# 24    -2.242      77355.692                  -71.930
# 25    -2.059      69979.507                  -77.636
# 26    -2.167      45420.488                  -76.879
#
#               test_min_feef_planner           test_avg_feef_planner  \
# 0                  -17682983000.000                  -708243650.000
# 1                -2378019600000.000                -84538474000.000
# 2                  -27839678000.000                 -1062982340.000
# 3                 -184654800000.000                 -7669472000.000
# 4  -370311120000000023131586560.000 -11572221999999999979552768.000
# 5        -100605230000000008192.000        -3143913300000000000.000
# 6                 -488738420000.000                -15951098000.000
# 7                           121.299                           0.034
# 8                           134.093                           0.279
# 9                           126.258                           0.064
# 10                          124.289                           0.077
# 11                          133.622                           0.083
# 12                          146.247                           0.203
# 13                          140.820                           0.068
# 14                          138.628                           0.161
# 15                          138.634                           0.030
# 16                          134.817                           0.062
# 17                          138.491                           0.029
# 18                          135.731                           0.036
# 19                          144.884                           0.094
# 20                          142.865                           0.073
# 21                          141.578                           0.106
# 22                          144.900                           0.106
# 23                          149.204                           0.141
# 24                          140.677                           0.031
# 25                          143.743                           0.264
# 26                          141.885                           0.028
#
#     test_max_feef_planner  test_avg_reward_planner  test_min_reward_planner  \
# 0          1448501000.000                  -42.960                  -81.660
# 1            64613124.000                  -64.450                 -155.776
# 2          1233803300.000                  -64.470                 -126.308
# 3          4633489000.000                  -69.929                 -153.397
# 4           149574140.000                  -64.345                 -131.331
# 5           300197000.000                  -61.913                 -154.055
# 6        153961710000.000                  -63.974                 -145.337
# 7                  -2.223               -77166.593                   22.879
# 8                  -1.994               305620.459                   73.432
# 9                  -2.405              4978901.245                  -14.089
# 10                 -2.281               -83443.450                   11.111
# 11                 -2.377               -79797.161                   80.392
# 12                 -1.853                84702.227                   57.718
# 13                 -2.067               -62713.302                   62.712
# 14                 -2.100               -74968.422                   31.004
# 15                 -2.264               -78507.959                   21.528
# 16                 -2.319               -79267.027                  123.729
# 17                 -2.168               -51937.023                   38.983
# 18                 -2.421               -81055.791                   58.730
# 19                 -2.035               -63175.717                   22.744
# 20                 -2.367               -78800.239                   -7.692
# 21                 -2.090               -63082.602                   85.965
# 22                 -2.051               -68235.326                   66.008
# 23                 -1.925               -71355.290                    0.402
# 24                 -2.211               -77217.227                   41.264
# 25                 -1.794               -69837.559                   90.840
# 26                 -2.138               -45280.742                    7.884
#
#     Unnamed: 24
# 0           nan
# 1           nan
# 2           nan
# 3           nan
# 4           nan
# 5           nan
# 6           nan
# 7           nan
# 8           nan
# 9           nan
# 10          nan
# 11          nan
# 12          nan
# 13          nan
# 14          nan
# 15          nan
# 16          nan
# 17          nan
# 18          nan
# 19          nan
# 20          nan
# 21          nan
# 22          nan
# 23          nan
# 24          nan
# 25          nan
# 26          nan
#
# [27 rows x 26 columns]

# %%
start_point = 0
end = 7

mdrnn_vae_training = mdrnn_vae_training.iloc[start_point:end]

# %%
mdrnn_vae_training.plot('index', ['train_loss'])
plt.title('Summary losses')
#plt.ylim( -1e2, 1e3)
# Out:
# Text(0.5, 1.0, 'Summary losses')

# %%
mdrnn_vae_training.plot('index', ['test_loss'])
plt.title('Summary losses')
# Out:
# Text(0.5, 1.0, 'Summary losses')

# %%
mdrnn_vae_training.plot('index', ['test_max_reward_planner','test_avg_reward_planner' , 'test_min_reward_planner', 'test_std_reward_planner'])
plt.title('Rewards from Best Planner on Each Rollout')
# Out:
# Text(0.5, 1.0, 'Rewards from Best Planner on Each Rollout')

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
mdrnn_vae_training[['test_avg_reward_planner']].astype(float)
# Out:
#    test_avg_reward_planner
# 0                  -42.960
# 1                  -64.450
# 2                  -64.470
# 3                  -69.929
# 4                  -64.345
# 5                  -61.913
# 6                  -63.974

# %%
mdrnn_vae_training[['test_max_reward_planner', 'test_min_reward_planner', 'test_avg_reward_planner']]
# Out:
#    test_max_reward_planner  test_min_reward_planner  test_avg_reward_planner
# 0                   16.438                  -81.660                  -42.960
# 1                   42.219                 -155.776                  -64.450
# 2                    7.023                 -126.308                  -64.470
# 3                   58.672                 -153.397                  -69.929
# 4                   -1.024                 -131.331                  -64.345
# 5                   82.482                 -154.055                  -61.913
# 6                   68.919                 -145.337                  -63.974

# %%
mdrnn_vae_training['test_min_reward_planner']
# Out:
# 0    -81.660
# 1   -155.776
# 2   -126.308
# 3   -153.397
# 4   -131.331
# 5   -154.055
# 6   -145.337
# Name: test_min_reward_planner, dtype: float64

# %%
for val in ['test_max_feef_planner','test_avg_feef_planner' , 'test_min_feef_planner', 'test_std_feef_planner']:
    plt.figure()
    mdrnn_vae_training.plot('index', val)
    plt.show()

# %%
mdrnn_vae_training.plot('index', ['test_max_feef_planner','test_avg_feef_planner' , 'test_min_feef_planner', 'test_std_feef_planner'])
plt.title('FEEFs from Best Planner on Each Rollout')
plt.ylim(mdrnn_vae_training['test_min_feef_planner'].quantile(0.5), mdrnn_vae_training['test_min_feef_planner'].quantile(1.0))
# Out:
# (-488738420000.0, -17682983000.0)

# %% [markdown]
# # VAE losses

# %%
mdrnn_vae_training.plot('index', ['train_loss_vae', 'test_loss_vae'])
plt.title('VAE total loss')
# Out:
# Text(0.5, 1.0, 'VAE total loss')

# %%
mdrnn_vae_training.plot('index', ['train_recon', 'test_recon'])
plt.title('VAE Recon')
#plt.ylim( -1e2, 1e3)
# Out:
# Text(0.5, 1.0, 'VAE Recon')

# %%
mdrnn_vae_training.plot('index', ['train_kld','test_kld'])
plt.title('VAE KLDs')
# Out:
# Text(0.5, 1.0, 'VAE KLDs')

# %% [markdown]
# # MDRNN losses

# %%
mdrnn_vae_training
# Out:
#    index  train_gmm  train_loss_vae  train_bce  train_kld  train_recon  \
# 0      0     -2.178      -45081.655      0.000    124.433    45206.087
# 1      1     -2.214      -65275.458      0.000    125.267    65400.725
# 2      2     -2.259      -71545.864      0.000    122.140    71668.004
# 3      3     -2.246      -69529.859      0.000    121.632    69651.491
# 4      4     -2.370      -66538.684      0.000    128.470    66667.154
# 5      5     -2.348       12056.667      0.000    124.120   -11932.541
# 6      6     -2.423      -70597.419      0.000    131.575    70728.994
#
#    train_mse  train_loss_mdrnn  train_loss  test_bce  ...  test_loss_mdrnn  \
# 0      0.137            -2.042  -45083.696     0.000  ...           -2.085
# 1      0.196            -2.018  -65277.475     0.000  ...           -2.245
# 2      0.185            -2.074  -71547.938     0.000  ...           -1.947
# 3      0.196            -2.050  -69531.909     0.000  ...           -2.027
# 4      0.131            -2.239  -66540.923     0.000  ...           -1.791
# 5      0.171            -2.177   12054.491     0.000  ...           -2.105
# 6      0.150            -2.274  -70599.693     0.000  ...           -2.483
#
#    test_kld     test_recon  test_std_reward_planner  \
# 0   122.978      70159.308                   25.548
# 1   118.417      63233.985                   37.562
# 2   122.089      58694.632                   28.028
# 3   122.009      66276.087                   45.988
# 4   139.736      51288.793                   28.395
# 5   125.220      62471.429                   46.981
# 6   129.980 -174080480.386                   51.640
#
#              test_min_feef_planner           test_avg_feef_planner  \
# 0                 -17682983000.000                  -708243650.000
# 1               -2378019600000.000                -84538474000.000
# 2                 -27839678000.000                 -1062982340.000
# 3                -184654800000.000                 -7669472000.000
# 4 -370311120000000023131586560.000 -11572221999999999979552768.000
# 5       -100605230000000008192.000        -3143913300000000000.000
# 6                -488738420000.000                -15951098000.000
#
#    test_max_feef_planner  test_avg_reward_planner  test_min_reward_planner  \
# 0         1448501000.000                  -42.960                  -81.660
# 1           64613124.000                  -64.450                 -155.776
# 2         1233803300.000                  -64.470                 -126.308
# 3         4633489000.000                  -69.929                 -153.397
# 4          149574140.000                  -64.345                 -131.331
# 5          300197000.000                  -61.913                 -154.055
# 6       153961710000.000                  -63.974                 -145.337
#
#    Unnamed: 24
# 0          nan
# 1          nan
# 2          nan
# 3          nan
# 4          nan
# 5          nan
# 6          nan
#
# [7 rows x 26 columns]

# %%
mdrnn_vae_training.plot('index', ['train_loss_mdrnn', 'test_loss_mdrnn'])
plt.title('MDRNN Reward Predictions')
# Out:
# Text(0.5, 1.0, 'MDRNN Reward Predictions')

# %%
mdrnn_vae_training.plot('index', ['train_mse', 'test_mse'])
plt.title('MDRNN Reward Predictions')
# Out:
# Text(0.5, 1.0, 'MDRNN Reward Predictions')

# %%
mdrnn_vae_training.plot('index', ['train_gmm', 'test_gmm'])
plt.title('MDRNN GMM')
# Out:
# Text(0.5, 1.0, 'MDRNN GMM')

# %% [markdown]
# ## CTRL losses from CMA-ES

# %%
ctrl_training = pd.read_csv('../exp_dir/joint/ctrl_logger.txt', sep=' ')
ctrl_training.reset_index(inplace=True)
ctrl_training.head(20)
# Out:
#     index  generation  time  avg_rew  min_rew  max_rew  std_rew  dist_std  \
# 0       0           1   186   -44.87  -114.17    42.38    37.59   0.10000
# 1       1           2   371   -58.80   -99.06   -18.84    20.46   0.09932
# 2       2           3   553   -77.90  -131.80   -38.16    20.27   0.09869
# 3       3           4   742   -59.54   -83.47   -15.61    17.50   0.09809
# 4       4           5   934   -71.16  -102.35   -34.53    15.70   0.09752
# 5       5           1   189   -47.52   -81.92   -21.03    19.39   0.10000
# 6       6           2   378   -25.61   -71.20    92.89    35.14   0.09932
# 7       7           3   571   -31.12   -60.83    38.97    23.46   0.09869
# 8       8           4   761   -34.87   -58.01   -15.24    12.18   0.09810
# 9       9           5   952   -41.47   -67.40   -21.39    14.23   0.09753
# 10     10           1   189   -66.36   -92.65    -5.14    29.61   0.09699
# 11     11           2   385   -69.88   -93.30   -13.03    27.26   0.09646
# 12     12           3   580   -69.85   -85.69    -0.41    26.29   0.09595
# 13     13           4   775   -31.70   -84.49    11.54    27.37   0.09546
# 14     14           5   969   -68.44   -92.42   -17.94    26.71   0.09498
# 15     15           1   236   -53.60   -93.13    23.90    36.12   0.09451
# 16     16           2   430   -80.48   -92.79   -62.97     6.71   0.09406
# 17     17           3   627   -77.93   -84.66   -31.09    12.52   0.09362
# 18     18           4   817   -82.53   -85.20   -76.04     1.90   0.09319
# 19     19           5  1010   -71.79   -84.29   -19.75    18.73   0.09278
#
#     mean_run_time  max_run_time      avg_feef      min_feef     max_feef  \
# 0          979.81        1000.0 -1.073732e+08 -3.674780e+08   -8856252.0
# 1          971.01        1000.0 -5.309192e+07 -1.533834e+08  -20006486.0
# 2          924.56        1000.0 -1.138007e+08 -3.173062e+08  -25348064.0
# 3          980.82        1000.0 -5.264471e+07 -2.000322e+08  -10920720.0
# 4          975.89        1000.0 -1.249562e+08 -3.571849e+08  -20697808.0
# 5         1000.00        1000.0 -9.962144e+06 -3.633393e+07    -832397.0
# 6         1000.00        1000.0 -4.055991e+07 -1.254717e+08   -3143666.0
# 7         1000.00        1000.0 -5.172101e+07 -1.040552e+08  -10327345.0
# 8         1000.00        1000.0 -7.843077e+07 -1.362723e+08  -19268732.0
# 9         1000.00        1000.0 -1.266590e+08 -2.274661e+08  -31276722.0
# 10        1000.00        1000.0 -2.494814e+08 -1.144792e+09   -2438823.0
# 11        1000.00        1000.0 -2.931314e+08 -1.813752e+09    -326893.0
# 12        1000.00        1000.0 -1.897550e+08 -4.648456e+08  -66849908.0
# 13        1000.00        1000.0 -4.750276e+08 -1.073217e+09 -103004590.0
# 14        1000.00        1000.0 -2.547060e+09 -2.548370e+10  -98516490.0
# 15        1000.00        1000.0 -9.962397e+05 -1.554214e+07    1216207.5
# 16         991.40        1000.0 -3.233718e+06 -8.780290e+06      51461.0
# 17         986.90        1000.0 -4.074304e+06 -1.045441e+07   -1355099.2
# 18        1000.00        1000.0 -2.628768e+06 -4.613720e+06    -974977.0
# 19        1000.00        1000.0 -5.469328e+06 -1.765917e+07      37954.0
#
#         std_feef  Unnamed: 13
# 0   1.234808e+08          NaN
# 1   4.529390e+07          NaN
# 2   7.699742e+07          NaN
# 3   5.235288e+07          NaN
# 4   1.047135e+08          NaN
# 5   8.435982e+06          NaN
# 6   3.429460e+07          NaN
# 7   2.853345e+07          NaN
# 8   3.096346e+07          NaN
# 9   5.238292e+07          NaN
# 10  2.757397e+08          NaN
# 11  4.443013e+08          NaN
# 12  1.407324e+08          NaN
# 13  2.490874e+08          NaN
# 14  6.141686e+09          NaN
# 15  3.876498e+06          NaN
# 16  2.094065e+06          NaN
# 17  2.187790e+06          NaN
# 18  9.229803e+05          NaN
# 19  4.612256e+06          NaN

# %%
ctrl_training.plot('index', ['max_rew', 'min_rew', 'avg_rew'])

# %%
plt.figure()
ctrl_training.plot('index', ['max_feef', 'min_feef', 'avg_feef'])
plt.ylim(-1e8, -1e2)
plt.show()
